# %% [markdown]
# ## Check Whether a String is Palindrome or Not

# %%
text = input("enter the anything here :: ")
reverse = text[::-1]
if text == reverse :
    print("the given text is palindrome")
else :
    print("the given number is not palindrome ")
# Out:
# the given number is not palindrome

# %%
text = input("enter  anything here ::")
reverse = text[::-1]
if text == reverse :
    print(f"the given text {text} is palindrome")
else:
    print(f"the given text {text} is not palindrome ")
# Out:
# the given text noon is palindrome
