# %% [markdown]
# ## Python Program to Safely Create a Nested Directory

# %%
from pathlib import Path 
Path("C:/Users/maana/OneDrive/Desktop/CERTIFICATES/new_dict/demo.dict").mkdir(parents=True,exist_ok=True)
