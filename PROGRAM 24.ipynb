# %% [markdown]
# ## 24TH MINI PROGRAM IN PYTHON PROGRAMMING
#
# ### PYTHON PROGRAM TO FIND THE FACTOR OF A NUMBER

# %%
num = int(input("enter the number "))
for i in range(1,num+1):
    if num % i == 0:
        print(i)

# %%
num = int(input("enter the number "))
for i in range (1,num+1):
    if num % i == 0 :
        print(i)

# %%
num = int(input("enter the number "))
for i in range (1,num+1):
    if num % i == 0:
        print(i)
