# %% [markdown]
# ### 35TH MINI PROGRAM IN PYTHON PROGRAMMING
#
# ## COLORTEXT IN PYTHON PROGRAMMING

# %%
import colorama
from colorama import Fore, Back, Style

colorama.init(autoreset=True)

print(Fore.BLUE+Back.YELLOW+ "Hi Name is SALMAN "+ Fore.BLUE+Back.YELLOW+ "I am Data Science Student")
print(Back.CYAN+ "Hi My Name is SALMAN")
print(Fore.RED + Back.GREEN+ "Hi i'm still here")
# Out:
# Hi Name is SALMAN I am Data Science Student
# Hi My Name is SALMAN
# Hi i'm still here
