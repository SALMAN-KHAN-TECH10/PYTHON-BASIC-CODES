# %% [markdown]
# 7TH MINI PROJECT IN PYTHON
#
# TO CHECK WHETHER NUMBER IS EVEN OR ODD

# %%
NUM= int(input("enter the number "))
if NUM % 2 == 0:
    print("THE ENTER NUMBER IS EVEN ")
elif NUM % 2 !=0:
    print("THE ENTER NUMBER IS ODD")
else:
    print("INVALID INPUT ")
# Out:
# THE ENTER NUMBER IS EVEN

# %%
num=int(input("enter the number "))
if num %2==0:
    print("the enter number is even ")
elif num%2 !=0:
    print("the enter number is odd")
else:
    print("enter the valid input")
# Out:
# the enter number is odd
