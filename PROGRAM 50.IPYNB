# %% [markdown]
# ### How to Copy Contents of One File to Another File using Python Codes?

# %%
from shutil import copyfile
try:
copyfile("enter your url here and the program will run ")
except(TypeError , IndentationError ) as a:
    print("paste your url here and the program will run ")
# Out:
#   Cell In[8], line 3
#     copyfile("enter your url here and the program will run ")
#     ^
# IndentationError: expected an indented block after 'try' statement on line 2
