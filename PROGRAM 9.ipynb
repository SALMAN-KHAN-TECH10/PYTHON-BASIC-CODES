# %% [markdown]
# 9TH PROGRAM IN PYTHON PROGRAMMING
#
# FIND THE LARGEST NUMBER AMONG THREE NUMBERS

# %%
NUM1 = int(input("ENTER THE NUMBER "))
NUM2= int(input("ENTER THE NUMBER "))
NUM3= int(input("ENTER THE NUMBER "))
if(NUM1>NUM2) and (NUM1 >NUM3):
    print(f"{NUM1} NUMBER 1 IS THE LARGEST NUMBER")
elif(NUM2 > NUM1) and (NUM2 > NUM3):
    print(f"{NUM2} NUMBER 2 IS THE LARGEST NUMBER")
else:
    print(f"{NUM3} NUMBER 3 IS THE LARGEST NUMBER")
# Out:
# 5984 NUMBER 2 IS THE LARGEST NUMBER

# %%
num1=int(input("enter the first number ::"))
num2=int(input("enter the second number ::"))
num3=int(input("enter the third number ::"))
if (num1 > num2) and (num1 > num3 ):
    print(f"the largest number is the first one :: {num1}")
elif (num2 > num1)  and(num2 > num3):
    print(f"the largest number is the second one :: {num2}")
else:
    print(f"the largest number is the third one :: {num3}")
# Out:
# the largest number is the second one :: 65
