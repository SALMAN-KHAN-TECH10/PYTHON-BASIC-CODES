# %% [markdown]
# ## Python Program to Sort a Dictionary by Value

# %%
# SOLUTION 1 SORT THE DICTIONARY BY VAUES 
marks = {"SALMAN":86,"AHMAD":77,"ALI":90}
SORTED_VALUES = sorted(marks.items(),key = lambda x = x[1])
print()
