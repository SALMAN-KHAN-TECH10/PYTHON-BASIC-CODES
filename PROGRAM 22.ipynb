# %% [markdown]
# ## 22TH MINI PROGRAM IN PYTHON PROGRAMMING
#
# ## FIND ASCII VALUES OF CHARACTER

# %%
char = "h"
print(f"the ASCII value of the char is " , ord(char))
# Out:
# the ASCII value of the char is  104
