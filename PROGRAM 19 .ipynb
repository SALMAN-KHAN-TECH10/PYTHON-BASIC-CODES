# %% [markdown]
# ##

# %% [markdown]
# ## 19TH MINI PROGRAM IN PYTHON PROGRAMMING
#
# #### PYTHON PROGRAM TO DISPLAY THE POWER OF 2 USING LAMBDA FUNCTION

# %%
n_terms= int(input("enter the number of terms "))
result = list(map(lambda x : 2 ** x, range(n_terms+1)))
# print(result)
for i in range(n_terms+1):
    print(f"the value of 2 raised to the power of {i} is {result[i]}")
# Out:
# the value of 2 raised to the power of 0 is 1
# the value of 2 raised to the power of 1 is 2
# the value of 2 raised to the power of 2 is 4
# the value of 2 raised to the power of 3 is 8
# the value of 2 raised to the power of 4 is 16
# the value of 2 raised to the power of 5 is 32
# the value of 2 raised to the power of 6 is 64
# the value of 2 raised to the power of 7 is 128
# the value of 2 raised to the power of 8 is 256

# %%
n_terms = int(input("enter the number of terms"))
result=list(map(lambda x :2 ** x , range(n_terms+1)))
for i in range(n_terms+1):
    print(f"the value of 2 raised to the power of {i} if {result[i]}")
# Out:
# the value of 2 raised to the power of 0 if 1
# the value of 2 raised to the power of 1 if 2
# the value of 2 raised to the power of 2 if 4
# the value of 2 raised to the power of 3 if 8
# the value of 2 raised to the power of 4 if 16
# the value of 2 raised to the power of 5 if 32
# the value of 2 raised to the power of 6 if 64
# the value of 2 raised to the power of 7 if 128
# the value of 2 raised to the power of 8 if 256
# the value of 2 raised to the power of 9 if 512
# the value of 2 raised to the power of 10 if 1024
# the value of 2 raised to the power of 11 if 2048
# the value of 2 raised to the power of 12 if 4096
# the value of 2 raised to the power of 13 if 8192
# the value of 2 raised to the power of 14 if 16384
# the value of 2 raised to the power of 15 if 32768
# the value of 2 raised to the power of 16 if 65536
# the value of 2 raised to the power of 17 if 131072
# the value of 2 raised to the power of 18 if 262144
# the value of 2 raised to the power of 19 if 524288
# ...
