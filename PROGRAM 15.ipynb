# %% [markdown]
# ## 15TH MINI PROGRAM IN PYTHON PROGRAMMING
#
# ### PYTHON PROGRAM TO DISPLAY THE MULTIPLICATION TABLE

# %%
num = int(input("enter the number "))
for i in range(1,11):
    print(f"{num} X {i} = {num*i}")
# Out:
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# 7 X 10 = 70

# %%
num = int(input("enter the number you want the table of ::"))
for i in range(1,11):
    print(f"{num} X {i} = {num*i}")
# Out:
# 44 X 1 = 44
# 44 X 2 = 88
# 44 X 3 = 132
# 44 X 4 = 176
# 44 X 5 = 220
# 44 X 6 = 264
# 44 X 7 = 308
# 44 X 8 = 352
# 44 X 9 = 396
# 44 X 10 = 440
